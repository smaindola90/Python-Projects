# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shubham Maindola**
#
# Student

# %% [markdown]
# *I am interested in data science because I always liked computer science but for some reasons, I wasn't able to get a computer science degree. So I got a degree in mathematics, and Data Science perfectly connects my educational background to my dream.*

# %% [markdown]
# ### The following code in cell 5 will tell us the product of two variables.

# %%
a = 23
b = 10
print (a*b)
# Out:
# 230

# %% [markdown]
# <hr>
# <a href="https://www.ibm.com/">Hyperlink</a>
#
# ![1933166.jpg](attachment:113d082a-1719-4f71-83da-89dd05217462.jpg)
#
#  - Name
#  - Subject
#  - Class
#  - Roll Number
#  - School
#  - Address
#  - Contact No.
